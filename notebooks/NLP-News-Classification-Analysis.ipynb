# %% [markdown]
# # News Classification - Analysis

# %% [markdown]
# **Haber Kaynağı:** https://nayn.co/

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 

import warnings
warnings.filterwarnings('ignore')
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df_2018 = pd.read_csv("https://github.com/naynco/nayn.data/raw/master/nayn.co-2018.csv", engine='python', encoding='utf-8', error_bad_lines=False)
# Out:
# Skipping line 22289: unexpected end of data

# %%
df_2018_ = df_2018[df_2018['Content'].notnull() & df_2018['Title'].notnull()]
#df_2018_.to_pickle("../../datasets/naynco/nayn.co-2018.pkl")

df_2018_.head()
# Out:
#       id  ...                                          Permalink
# 0  99370  ...  https://nayn.co/almanya-turkiyedeki-asgari-ucr...
# 1  99383  ...  https://nayn.co/whatsapp-coktu-ilk-aciklama-bt...
# 2  99401  ...  https://nayn.co/fatih-terim-vagner-lovein-tran...
# 3  99402  ...    https://nayn.co/kosta-rikada-ucak-dustu-12-olu/
# 4  99403  ...  https://nayn.co/milli-piyango-yilbasi-cekilisi...
#
# [5 rows x 5 columns]

# %%
df_2017 = pd.read_csv("https://github.com/naynco/nayn.data/raw/master/nayn.co-2017.csv", engine='python', encoding='utf-8', error_bad_lines=False)
# Out:
# Skipping line 12246: unexpected end of data

# %%
df_2017_ = df_2017[df_2017['Content'].notnull() & df_2017['Title'].notnull()]
#df_2017_.to_pickle("../../datasets/naynco/nayn.co-2017.pkl")

df_2017_.head()
# Out:
#       id  ...                                          Permalink
# 0  55681  ...     https://nayn.co/2017-bir-saniye-daha-uzayacak/
# 1  55682  ...  https://nayn.co/sisme-noel-babayi-sunnet-edip-...
# 2  55685  ...  https://nayn.co/otoyol-yuzde-15-bogaz-kopruler...
# 3  55686  ...  https://nayn.co/liseli-sude-sabah-karanlikta-o...
# 4  55687  ...  https://nayn.co/ozal-thatcher-gorusmesinin-tut...
#
# [5 rows x 5 columns]

# %%
df_2016 = pd.read_csv("https://github.com/naynco/nayn.data/raw/master/nayn.co-2016.csv", engine='python', encoding='utf-8', error_bad_lines=False)

# %%
df_2016_ = df_2016[df_2016['Content'].notnull() & df_2016['Title'].notnull()]
#df_2016_.to_pickle("../../datasets/naynco/nayn.co-2016.pkl")

df_2016_.head()
# Out:
#    id  ...                                          Permalink
# 0  18  ...  https://nayn.co/kuba-milli-takimi-oyuncularini...
# 1  21  ...  https://nayn.co/daily-telegraph-suriyelilere-v...
# 2  24  ...  https://nayn.co/aymden-yuksek-sesli-ezan-sikay...
# 3  31  ...  https://nayn.co/istanbuldaki-teror-saldirisi-e...
# 4  34  ...  https://nayn.co/turkiye-rusyadaki-en-populer-d...
#
# [5 rows x 5 columns]

# %%
df_2017_['Date'].value_counts()
# Out:
# 2017-06-12    64
# 2017-10-09    57
# 2017-10-23    56
# 2017-10-13    55
# 2017-06-14    54
#               ..
# 2017-08-13     9
# 2016-12-31     9
# 2017-09-03     6
# 2017-07-16     6
# 2016-11-06     1
# Name: Date, Length: 365, dtype: int64

# %%
df_2018_['Date'].value_counts()
# Out:
# 2018-04-23    109
# 2018-11-15    105
# 2018-06-14    105
# 2018-04-19    100
# 2018-04-10     99
#              ...
# 2018-03-04     26
# 2018-02-17     25
# 2018-04-01     22
# 2018-01-06     22
# 2017-12-31      2
# Name: Date, Length: 366, dtype: int64

# %%
df_2018_['title_length'] = df_2018_['Title'].str.len()
df_2018_['content_length'] = df_2018_['Content'].str.len()

df_2017_['title_length'] = df_2017_['Title'].str.len()
df_2017_['content_length'] = df_2017_['Content'].str.len()

df_2016_['title_length'] = df_2016_['Title'].str.len()
df_2016_['content_length'] = df_2016_['Content'].str.len()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#df_2018_.to_pickle("../../datasets/naynco/nayn.co-2018.pkl")
#df_2017_.to_pickle("../../datasets/naynco/nayn.co-2017.pkl")
#df_2016_.to_pickle("../../datasets/naynco/nayn.co-2016.pkl")

# %%
df_2018_.sort_values(by=['content_length'],  ascending=True).reset_index()
# Out:
#        index      id  ... title_length content_length
# 0      11608  143895  ...           67             28
# 1      11607  143894  ...           47             28
# 2      11605  143890  ...           44             28
# 3      19122  165579  ...           85             43
# 4       3685  115359  ...           92             51
# ...      ...     ...  ...          ...            ...
# 22275   6756  127607  ...           30          20069
# 22276  22098  181383  ...           50          20328
# 22277  17784  161747  ...          124          20407
# 22278  15393  154981  ...          113          22775
# 22279  12985  148047  ...           86          27019
#
# [22280 rows x 8 columns]

# %%
fig, ax = plt.subplots(1, 1, figsize=(35,7))
sns.countplot(x = 'Date', data = df_2017_)

# %%
fig, ax = plt.subplots(1, 1, figsize=(35,7))
sns.countplot(x = 'Date', data = df_2018_)

# %%
df_2018_['Title'].value_counts()
# Out:
# İsrail'den Gazze'ye hava saldırısı                                                                                               4
# TSK'dan Kuzey Irak'a hava harekatı                                                                                               3
# Cüce gezegen Ceres organik madde açısından zengin olabilir                                                                       2
# Dolar 4 lirayı aştı                                                                                                              2
# Facebook ve Instagram çöktü                                                                                                      2
#                                                                                                                                 ..
# CHP'li Tanal'dan seçim sonuçlarına tepki: Suriyelilerden illallah eden Urfa, Antep, Kilis yüzde 51 oy veriyorsa bir sorun var    1
# ...
